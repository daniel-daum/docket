# %%
import httpx

# %%
r = httpx.get('https://www.jag.navy.mil/api/tables/decisions-opinions/data/?page=57&page_size=100&q=&ordering=-data__6e61b248-ef67-423e-b321-f2ed8ad05728&_=1734932308474')

# %%
r.status_code
# Out:
# 200

# %%
a = r.json()
a.keys()

# %%
a.get('results')
# Out:
# [{'id': 6640,
#   'data': {'6e61b248-ef67-423e-b321-f2ed8ad05728': '2004-02-27',
#    '80dedfc1-74a9-4372-a36f-8736c6baf754': '200200121',
#    '9152980f-7bd6-4b48-8130-10500cda8cca': None,
#    '9a84d8ce-017d-4a4b-821f-2fa33b700b0c': 'U.S. v. Burchett'},
#   'documents': [{'document': {'id': 4571,
#      'title': 'U.S. v. Burchett',
#      'is_searchable': True,
#      'search_description': '',
#      'mime_type': 'application/pdf',
#      'created_at': '2024-05-04T01:34:23.285879Z',
#      'file_type': 6,
#      'file_type__label': 'PDF',
#      'download_url': 'https://www.jag.navy.mil/documents/4571/200200121_UNPUB.pdf'},
#     'key': 'd1a20eee-610b-40f0-b8a7-d2316a4f1d5c'}],
#   'media': []},
#  {'id': 6641,
#   'data': {'6e61b248-ef67-423e-b321-f2ed8ad05728': '2004-02-24',
#    '80dedfc1-74a9-4372-a36f-8736c6baf754': '200101126',
#    '9152980f-7bd6-4b48-8130-10500cda8cca': None,
#    '9a84d8ce-017d-4a4b-821f-2fa33b700b0c': 'U.S. v. Hurd'},
# ...
